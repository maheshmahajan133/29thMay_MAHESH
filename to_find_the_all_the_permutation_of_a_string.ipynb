# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshmahajan133/mahesh-mahajan-Branch1/blob/29maybranch/to_find_the_all_the_permutation_of_a_string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def permute(s):
  out=[]
  if len(s)==1:
    return [s]
  else:
    for i,let in enumerate(s):
      for perm in permute(s[:i]+s[i+1:]):
        out+=[let+perm]
  return out
permute('abxme')
# Out:
# ['abxme',
#  'abxem',
#  'abmxe',
#  'abmex',
#  'abexm',
#  'abemx',
#  'axbme',
#  'axbem',
#  'axmbe',
#  'axmeb',
#  'axebm',
#  'axemb',
#  'ambxe',
#  'ambex',
#  'amxbe',
#  'amxeb',
#  'amebx',
#  'amexb',
#  'aebxm',
#  'aebmx',
#  'aexbm',
#  'aexmb',
#  'aembx',
#  'aemxb',
#  'baxme',
#  'baxem',
#  'bamxe',
#  'bamex',
#  'baexm',
#  'baemx',
#  'bxame',
#  'bxaem',
#  'bxmae',
#  'bxmea',
#  'bxeam',
#  'bxema',
#  'bmaxe',
#  'bmaex',
#  'bmxae',
#  'bmxea',
#  'bmeax',
#  'bmexa',
#  'beaxm',
#  'beamx',
#  'bexam',
#  'bexma',
#  'bemax',
#  'bemxa',
#  'xabme',
#  'xabem',
#  'xambe',
#  'xameb',
#  'xaebm',
#  'xaemb',
#  'xbame',
#  'xbaem',
#  'xbmae',
#  'xbmea',
#  'xbeam',
#  'xbema',
#  'xmabe',
#  'xmaeb',
#  'xmbae',
#  'xmbea',
#  'xmeab',
#  'xmeba',
#  'xeabm',
#  'xeamb',
#  'xebam',
#  'xebma',
#  'xemab',
#  'xemba',
#  'mabxe',
#  'mabex',
#  'maxbe',
#  'maxeb',
#  'maebx',
#  'maexb',
#  'mbaxe',
#  'mbaex',
#  'mbxae',
#  'mbxea',
#  'mbeax',
#  'mbexa',
#  'mxabe',
#  'mxaeb',
#  'mxbae',
#  'mxbea',
#  'mxeab',
#  'mxeba',
#  'meabx',
#  'meaxb',
#  'mebax',
#  'mebxa',
#  'mexab',
#  'mexba',
#  'eabxm',
#  'eabmx',
#  'eaxbm',
#  'eaxmb',
#  'eambx',
#  'eamxb',
#  'ebaxm',
#  'ebamx',
#  'ebxam',
#  'ebxma',
#  'ebmax',
#  'ebmxa',
#  'exabm',
#  'examb',
#  'exbam',
#  'exbma',
#  'exmab',
#  'exmba',
#  'emabx',
#  'emaxb',
#  'embax',
#  'embxa',
#  'emxab',
#  'emxba']
